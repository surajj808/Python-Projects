# %% [markdown]
# # Problem Statement:

# %% [raw]
# Over the years, the company has collected details and gathered a lot of information about individuals. The management wants to build an intelligent system from the data to determine the presence or absence of smoking in a person through bio-signals. Given a person’s information, build a machine  earning model that can classify the presence or absence of smoking.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('smoking.csv')
df
# Out:
#           ID gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0          0      F   40         155          60       81.3             1.2
# 1          1      F   40         160          60       81.0             0.8
# 2          2      M   55         170          60       80.0             0.8
# 3          3      M   40         165          70       88.0             1.5
# 4          4      F   40         155          60       86.0             1.0
# ...      ...    ...  ...         ...         ...        ...             ...
# 55687  55676      F   40         170          65       75.0             0.9
# 55688  55681      F   45         160          50       70.0             1.2
# 55689  55683      F   55         160          50       68.5             1.0
# 55690  55684      M   60         165          60       78.0             0.8
# 55691  55691      M   55         160          65       85.0             0.9
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55692 entries, 0 to 55691
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   55692 non-null  int64
#  1   gender               55692 non-null  object
#  2   age                  55692 non-null  int64
#  3   height(cm)           55692 non-null  int64
#  4   weight(kg)           55692 non-null  int64
#  5   waist(cm)            55692 non-null  float64
#  6   eyesight(left)       55692 non-null  float64
#  7   eyesight(right)      55692 non-null  float64
#  8   hearing(left)        55692 non-null  float64
#  9   hearing(right)       55692 non-null  float64
#  10  systolic             55692 non-null  float64
#  11  relaxation           55692 non-null  float64
#  12  fasting blood sugar  55692 non-null  float64
#  13  Cholesterol          55692 non-null  float64
#  14  triglyceride         55692 non-null  float64
# ...

# %%
df.describe()
# Out:
#                  ID           age    height(cm)    weight(kg)     waist(cm)  \
# count  55692.000000  55692.000000  55692.000000  55692.000000  55692.000000
# mean   27845.500000     44.182917    164.649321     65.864936     82.046418
# std    16077.039933     12.071418      9.194597     12.820306      9.274223
# min        0.000000     20.000000    130.000000     30.000000     51.000000
# 25%    13922.750000     40.000000    160.000000     55.000000     76.000000
# 50%    27845.500000     40.000000    165.000000     65.000000     82.000000
# 75%    41768.250000     55.000000    170.000000     75.000000     88.000000
# max    55691.000000     85.000000    190.000000    135.000000    129.000000
#
#        eyesight(left)  eyesight(right)  hearing(left)  hearing(right)  \
# count    55692.000000     55692.000000   55692.000000    55692.000000
# mean         1.012623         1.007443       1.025587        1.026144
# std          0.486873         0.485964       0.157902        0.159564
# ...

# %%
df.isna().values.any()
# Out:
# False

# %%
df.duplicated().unique()
# Out:
# array([False])

# %%
df['oral'].unique()
# Out:
# array(['Y'], dtype=object)

# %%
df.drop(columns = ['ID','oral'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#   gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0      F   40         155          60       81.3             1.2
# 1      F   40         160          60       81.0             0.8
# 2      M   55         170          60       80.0             0.8
# 3      M   40         165          70       88.0             1.5
# 4      F   40         155          60       86.0             1.0
#
#    eyesight(right)  hearing(left)  hearing(right)  systolic  ...    LDL  \
# 0              1.0            1.0             1.0     114.0  ...  126.0
# 1              0.6            1.0             1.0     119.0  ...  127.0
# 2              0.8            1.0             1.0     138.0  ...  151.0
# 3              1.5            1.0             1.0     100.0  ...  226.0
# 4              1.0            1.0             1.0     120.0  ...  107.0
#
#    hemoglobin  Urine protein  serum creatinine   AST   ALT   Gtp  \
# 0        12.9            1.0               0.7  18.0  19.0  27.0
# ...

# %% [markdown]
# # Data Visualization

# %%
sns.barplot(x = df['gender'], y = df['smoking'])
plt.show()

# %% [raw]
# Mens are the mojority smokers!

# %%
plt.figure(figsize = (10,5))
# plt.pie(df['smoking'].value_counts(), autopct = '%0.2f')
# plt.title('Smoking')
df['smoking'].value_counts().plot.pie(autopct = '%.2f')
plt.show()

# %% [raw]
# 36.73% of the people smokes ciggarette.

# %%
plt.figure(figsize = (9,6))
sns.histplot(x = df['age'], hue = df['smoking'])
plt.show()

# %% [raw]
# Most number of smokers are having the age of 40

# %%
#Checking outliers

for i in df.columns:
    if (df[i].dtypes != 'object'):
        sns.boxplot(df[i])
        plt.show()

# %% [raw]
# Here outliers represent natural variations in the population, and they should be left as is in the dataset.
# These are called true outliers. Therefore for this dataset we will not remove outliers.

# %%
# Perform Label Encoding for Categorical values in the data

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df['gender'] = le.fit_transform(df['gender'])
df['tartar'] = le.fit_transform(df['tartar'])
df['dental caries'] = le.fit_transform(df['dental caries'])

# %% [markdown]
# # Feature Selection using Feature importance

# %%
x = df.drop('smoking', axis = 1)
y = df['smoking']

from sklearn.ensemble import ExtraTreesClassifier

model = ExtraTreesClassifier()
model.fit(x,y)

df1 = pd.Series(model.feature_importances_ , index = x.columns)

plt.figure(figsize = (8,8))
df1.nlargest(24).plot(kind = 'barh')
plt.show()

# %% [raw]
# Feature importance is a technique that calculate a score for all the input features for a given model. So out of 24 features we will select the
# top 15 features based on the score.

# %%
top_15 = df1.nlargest(15) # TOP 15 largest valued features selected for further.
print(top_15)
# Out:
# gender                 0.180657
# height(cm)             0.063874
# Gtp                    0.059302
# hemoglobin             0.059252
# triglyceride           0.054687
# age                    0.043716
# waist(cm)              0.042426
# HDL                    0.041174
# weight(kg)             0.040791
# fasting blood sugar    0.039368
# LDL                    0.038941
# systolic               0.038822
# ALT                    0.038775
# serum creatinine       0.038690
# relaxation             0.038604
# dtype: float64

# %% [markdown]
# # Logistic Regression

# %%
x = df[['gender','height(cm)','Gtp','hemoglobin','triglyceride','age','waist(cm)','HDL','weight(kg)','fasting blood sugar','LDL','ALT','systolic','serum creatinine','relaxation']]
y = df['smoking']

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2, random_state=10)

x_train.shape, x_test.shape, y_train.shape
# Out:
# ((44553, 15), (11139, 15), (44553,))

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()

x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

x_train.shape, x_test.shape
# Out:
# ((44553, 15), (11139, 15))

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()

lr.fit(x_train,y_train)

y_pred = lr.predict(x_test)

from sklearn.metrics import accuracy_score, classification_report

print("Accuracy: ", accuracy_score(y_test,y_pred))
print("Classification Report: \n", classification_report(y_test,y_pred))
# Out:
# Accuracy:  0.7423467097585061
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.77      0.79      7087
#            1       0.63      0.70      0.66      4052
#
#     accuracy                           0.74     11139
#    macro avg       0.72      0.73      0.73     11139
# weighted avg       0.75      0.74      0.74     11139

# %% [raw]
# The accuracy of the logistic regression model is 74%

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier()
dt.fit(x_train,y_train)

y_pred = dt.predict(x_test)
print("Classification Report: \n", classification_report(y_test,y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.83      0.83      7087
#            1       0.70      0.72      0.71      4052
#
#     accuracy                           0.79     11139
#    macro avg       0.77      0.77      0.77     11139
# weighted avg       0.79      0.79      0.79     11139

# %% [raw]
# The accuracy of the Decision Tree model is 79%

# %% [markdown]
# # Bagging Classifier

# %% [raw]
# Bootstrap Aggregation or bagging involves taking multiple samples from the training dataset (with replacement) and training a model for each sample.

# %%
from sklearn.ensemble import BaggingClassifier

bg = BaggingClassifier(base_estimator = DecisionTreeClassifier(), n_estimators = 1000)
bg.fit(x_train,y_train).score(x_test,y_test)

y_pred = bg.predict(x_test)
print("Classification Report: \n", classification_report(y_test,y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.85      0.86      7087
#            1       0.75      0.79      0.77      4052
#
#     accuracy                           0.83     11139
#    macro avg       0.82      0.82      0.82     11139
# weighted avg       0.83      0.83      0.83     11139

# %% [raw]
# The accuracy of the Bagging Claasifier is 83%

# %% [markdown]
# # Bagging Algorithm – Extra Trees

# %%
from sklearn.ensemble import ExtraTreesClassifier

et = ExtraTreesClassifier(n_estimators = 1000, random_state = 11)
et.fit(x_train,y_train)

y_pred = et.predict(x_test)
print("Classification Report: \n", classification_report(y_test,y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.84      0.86      7087
#            1       0.75      0.81      0.78      4052
#
#     accuracy                           0.83     11139
#    macro avg       0.82      0.83      0.82     11139
# weighted avg       0.84      0.83      0.83     11139

# %% [raw]
# The accuracy with Extra Trees is also 83%. Hence, lets try for Random Forest for better accuracy.

# %% [markdown]
# # Bagging Algorithm – Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators = 1000)
rf.fit(x_train,y_train)

y_pred = rf.predict(x_test)
print("Classification Report: \n", classification_report(y_test,y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.85      0.87      7087
#            1       0.75      0.80      0.78      4052
#
#     accuracy                           0.83     11139
#    macro avg       0.82      0.82      0.82     11139
# weighted avg       0.83      0.83      0.83     11139

# %% [raw]
# The accuracy of Random Forest Classifier is also 83%.
